# %% [markdown]
# # Creating NFL Visualizations Using Team Logos

# %%
# Dependencies
import nfl_data_py as nfl
import pandas as pd
import numpy as np
import os
import urllib.request
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
# Pull the team description 
logos = nfl.import_team_desc()

logos.head()
# Out:
#   team_abbr          team_name  team_id  team_nick team_conf team_division  \
# 0       ARI  Arizona Cardinals     3800  Cardinals       NFC      NFC West
# 1       ATL    Atlanta Falcons      200    Falcons       NFC     NFC South
# 2       BAL   Baltimore Ravens      325     Ravens       AFC     AFC North
# 3       BUF      Buffalo Bills      610      Bills       AFC      AFC East
# 4       CAR  Carolina Panthers      750   Panthers       NFC     NFC South
#
#   team_color team_color2 team_color3 team_color4  \
# 0    #97233F     #000000     #ffb612     #a5acaf
# 1    #A71930     #000000     #a5acaf     #a30d2d
# 2    #241773     #9E7C0C     #9e7c0c     #c60c30
# 3    #00338D     #C60C30     #0c2e82     #d50a0a
# 4    #0085CA     #000000     #bfc0bf     #0085ca
#
#                                  team_logo_wikipedia  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...
# 4  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                       team_logo_espn  \
# 0  https://a.espncdn.com/i/teamlogos/nfl/500/ari.png
# 1  https://a.espncdn.com/i/teamlogos/nfl/500/atl.png
# 2  https://a.espncdn.com/i/teamlogos/nfl/500/bal.png
# 3  https://a.espncdn.com/i/teamlogos/nfl/500/buf.png
# 4  https://a.espncdn.com/i/teamlogos/nfl/500-dark...
#
#                                        team_wordmark  \
# 0  https://github.com/nflverse/nflfastR-data/raw/...
# 1  https://github.com/nflverse/nflfastR-data/raw/...
# 2  https://github.com/nflverse/nflfastR-data/raw/...
# 3  https://github.com/nflverse/nflfastR-data/raw/...
# 4  https://github.com/nflverse/nflfastR-data/raw/...
#
#                                 team_conference_logo  \
# 0  https://github.com/nflverse/nflfastR-data/raw/...
# 1  https://github.com/nflverse/nflfastR-data/raw/...
# 2  https://github.com/nflverse/nflfastR-data/raw/...
# 3  https://github.com/nflverse/nflfastR-data/raw/...
# 4  https://github.com/nflverse/nflfastR-data/raw/...
#
#                                     team_league_logo
# 0  https://raw.githubusercontent.com/nflverse/nfl...
# 1  https://raw.githubusercontent.com/nflverse/nfl...
# 2  https://raw.githubusercontent.com/nflverse/nfl...
# 3  https://raw.githubusercontent.com/nflverse/nfl...
# 4  https://raw.githubusercontent.com/nflverse/nfl...

# %%
# Keep only the necessary columns in the logos DataFrame
logos = logos[['team_abbr', 'team_logo_espn']]

# %%
# Initialize an empty list for the logo file paths
logo_paths = []

# Initialize an empty list for the team abbreviations
team_abbr = []

# Create a folder for the image files if it doesn't exist
folder_path = "logos"
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
# Pull the team logos from the URL and save them in the logos folder, save the file paths to
for team in range(len(logos)):
    urllib.request.urlretrieve(logos['team_logo_espn'][team], f"logos/{logos['team_abbr'][team]}.tif")
    logo_paths.append(f"logos/{logos['team_abbr'][team]}.tif")
    team_abbr.append(logos['team_abbr'][team])

# %%
# Create a dictionary to put logo_paths and team_abbr in
data = {'Team Abbr' : team_abbr, 'Logo Path' : logo_paths}

# Create a DataFrame from the dictionary
logo_df = pd.DataFrame(data)

logo_df.head()
# Out:
#   Team Abbr      Logo Path
# 0       ARI  logos/ARI.tif
# 1       ATL  logos/ATL.tif
# 2       BAL  logos/BAL.tif
# 3       BUF  logos/BUF.tif
# 4       CAR  logos/CAR.tif

# %%
# Load the NFL 2021 PBP data
pbp_df = nfl.import_pbp_data([2021])
# Out:
# 2021 done.
# Downcasting floats.

# %%
pbp_df
# Out:
#        play_id          game_id old_game_id home_team away_team season_type  \
# 0          1.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 1         40.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 2         55.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 3         76.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# 4        100.0  2021_01_ARI_TEN  2021091207       TEN       ARI         REG
# ...        ...              ...         ...       ...       ...         ...
# 50707   3930.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50708   3951.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50709   3968.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50710   3990.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
# 50711   4011.0   2021_22_LA_CIN  2022021300       CIN        LA        POST
#
#        week posteam posteam_type defteam  ... possession_team  \
# 0         1    None         None    None  ...
# 1         1     TEN         home     ARI  ...             ARI
# 2         1     TEN         home     ARI  ...             TEN
# 3         1     TEN         home     ARI  ...             TEN
# 4         1     TEN         home     ARI  ...             TEN
# ...     ...     ...          ...     ...  ...             ...
# 50707    22     CIN         home      LA  ...             CIN
# 50708    22    None         None    None  ...
# 50709    22     CIN         home      LA  ...             CIN
# 50710    22      LA         away     CIN  ...              LA
# 50711    22    None         None    None  ...
#
#        offense_formation offense_personnel  defenders_in_box  \
# 0                   None              None               NaN
# 1                   None              None               NaN
# 2             SINGLEBACK  1 RB, 2 TE, 2 WR               7.0
# 3                SHOTGUN  1 RB, 2 TE, 2 WR               7.0
# 4                SHOTGUN  1 RB, 1 TE, 3 WR               5.0
# ...                  ...               ...               ...
# 50707            SHOTGUN  1 RB, 1 TE, 3 WR               6.0
# 50708               None              None               NaN
# 50709            SHOTGUN  1 RB, 1 TE, 3 WR               6.0
# 50710               None  1 RB, 1 TE, 3 WR               6.0
# 50711               None              None               NaN
#
#        defense_personnel  number_of_pass_rushers  \
# 0                   None                     NaN
# 1                   None                     NaN
# 2       3 DL, 4 LB, 4 DB                     NaN
# 3       3 DL, 4 LB, 4 DB                     4.0
# 4       2 DL, 4 LB, 5 DB                     4.0
# ...                  ...                     ...
# 50707   2 DL, 3 LB, 6 DB                     NaN
# 50708               None                     NaN
# 50709   2 DL, 3 LB, 6 DB                     3.0
# 50710   4 DL, 2 LB, 5 DB                     NaN
# 50711               None                     NaN
#
#                                          offense_players  n_offense  \
# 0                                                               0.0
# 1      00-0032560;00-0036356;00-0035705;00-0036896;00...       11.0
# 2      00-0029413;00-0032764;00-0029701;00-0027648;00...       11.0
# 3      00-0029413;00-0032764;00-0029701;00-0027648;00...       11.0
# 4      00-0032355;00-0029413;00-0029701;00-0033455;00...       11.0
# ...                                                  ...        ...
# 50707  00-0032134;00-0032043;00-0036310;00-0033009;00...       11.0
# 50708                                                           0.0
# 50709  00-0032134;00-0032043;00-0036310;00-0033009;00...       11.0
# 50710  00-0036424;00-0032242;00-0034804;00-0034449;00...       11.0
# 50711                                                           0.0
#
#                                          defense_players  n_defense
# 0                                                               0.0
# 1      00-0032496;00-0036652;00-0032355;00-0033455;00...       11.0
# 2      00-0036356;00-0035705;00-0036933;00-0035236;00...       11.0
# 3      00-0036356;00-0035705;00-0036933;00-0035236;00...       11.0
# 4      00-0036356;00-0032127;00-0035705;00-0030528;00...       11.0
# ...                                                  ...        ...
# 50707  00-0033072;00-0035663;00-0025424;00-0035667;00...       11.0
# 50708                                                           0.0
# 50709  00-0033072;00-0035663;00-0025424;00-0035667;00...       11.0
# 50710  00-0034834;00-0032379;00-0033548;00-0034675;00...       11.0
# 50711                                                           0.0
#
# [50712 rows x 382 columns]

# %%
pbp_df.columns
# Out:
# Index(['play_id', 'game_id', 'old_game_id', 'home_team', 'away_team',
#        'season_type', 'week', 'posteam', 'posteam_type', 'defteam',
#        ...
#        'possession_team', 'offense_formation', 'offense_personnel',
#        'defenders_in_box', 'defense_personnel', 'number_of_pass_rushers',
#        'offense_players', 'n_offense', 'defense_players', 'n_defense'],
#       dtype='object', length=382)

# %%
# Filter down to just the necessary columns
pbp_df = pbp_df[['posteam', ]]

# %%
plt.rcParams["figure.figsize"] = [20, 14]
plt.rcParams["figure.autolayout"] = True


def getImage(path):
   return OffsetImage(plt.imread(path, format="tif"), zoom=.15)


x = np.random.randint(1, high=100, size=32)
y = np.random.randint(1, high=100, size=32)
fig, ax = plt.subplots()
for x0, y0, path in zip(x, y, paths):
   ab = AnnotationBbox(getImage(path), (x0, y0), frameon=False)
   ax.add_artist(ab)
plt.xticks(range(100));
plt.yticks(range(100));
plt.savefig("hello")
